# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_json("./initial_files_invalid_links.json")
df.head()
# Out:
#                                                 file  \
# 0  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 1  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 2  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 3  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 4  /aiforce/aiforce-dms/app/assets/data/uploaded_...
#
#                                             href  \
# 0            ../Xerox/0001558849.html#wwID0EL1QS
# 1  ../Xerox/browser_requirements.html#wwID0EDERS
# 2                       0001485251.html#ID0E4MFM
# 3                       0001508433.html#ID0E4MFM
# 4                       0001484998.html#ID0EVCGO
#
#                                     resolved_url         status  \
# 0            ../Xerox/0001558849.html#wwID0EL1QS  Not Validated
# 1  ../Xerox/browser_requirements.html#wwID0EDERS  Not Validated
# 2                       0001485251.html#ID0E4MFM  Not Validated
# 3                       0001508433.html#ID0E4MFM  Not Validated
# ...

# %%
len(df["file"].unique())
# Out:
# 446

# %%
df = df[df['error'] != "Local/relative path cannot be verified without a base directory"]
len(df)
# Out:
# 20

# %%
df.head()
# Out:
#                                                   file  \
# 183  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 189  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 190  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 380  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 408  /aiforce/aiforce-dms/app/assets/data/uploaded_...
#
#                                                   href  \
# 183                   https://dtsc.ca.gov/perchlorate/
# 189  https://www.office.xerox.com/cgi-bin/printer.p...
# 190  https://www.office.xerox.com/cgi-bin/printer.p...
# 380  https://www.office.xerox.com/cgi-bin/printer.p...
# 408                   https://dtsc.ca.gov/perchlorate/
#
#                                           resolved_url            status  \
# 183                   https://dtsc.ca.gov/perchlorate/  Connection Error
# 189  https://www.office.xerox.com/cgi-bin/printer.p...  Connection Error
# 190  https://www.office.xerox.com/cgi-bin/printer.p...  Connection Error
# ...

# %%
df = pd.read_json("./new_initial_files_invalid_links.json")
df.head()
# Out:
#                                                 file  \
# 0  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 1  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 2  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 3  /aiforce/aiforce-dms/app/assets/data/uploaded_...
# 4  /aiforce/aiforce-dms/app/assets/data/uploaded_...
#
#                                                 href  \
# 0      ../Xerox/browser_requirements.html#wwID0EDERS
# 1  https://www.office.xerox.com/cgi-bin/printer.p...
# 2  https://www.office.xerox.com/cgi-bin/printer.p...
# 3                   https://dtsc.ca.gov/perchlorate/
# 4  https://www.office.xerox.com/cgi-bin/printer.p...
#
#                                         resolved_url            status  \
# 0      ../Xerox/browser_requirements.html#wwID0EDERS               404
# 1  https://www.office.xerox.com/cgi-bin/printer.p...           Timeout
# 2  https://www.office.xerox.com/cgi-bin/printer.p...           Timeout
# ...

# %%
df = df.groupby
